# %%
import pandas as pd

df = pd.read_excel("/teamspace/studios/this_studio/lung_sound_project/data/raw/fraiwan/Data annotation.xlsx")
print(df["Diagnosis"].astype(str).str.strip().str.lower().value_counts().head(50))
# Out:
# Diagnosis
# nan                              42
# n                                35
# asthma                           32
# heart failure                    18
# copd                              9
# pneumonia                         5
# lung fibrosis                     4
# bron                              3
# heart failure + copd              2
# plueral effusion                  2
# heart failure + lung fibrosis     1
# asthma and lung fibrosis          1
# Name: count, dtype: int64

# %%
from pathlib import Path

diags = set()
for f in Path("data/raw/fraiwan/audio").glob("*.wav"):
    diag = f.stem.split("_",1)[1].split(",")[0].strip().lower()
    diags.add(diag)

print(sorted(diags))
# Out:
# []
